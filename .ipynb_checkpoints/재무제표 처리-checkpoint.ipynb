# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_financial_statements = pd.read_csv('재무제표.csv')
df_financial_statements
# Out:
#                                  Unnamed: 0        매출액     영업이익 영업이익(발표기준)  \
# 0     2017/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)  2,395,754  536,450    536,450
# 1     2018/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)  2,437,714  588,867    588,867
# 2     2019/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)  2,304,009  277,685    277,685
# 3     2020/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)  2,368,070  359,939    359,939
# 4     2021/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)  2,796,048  516,339    516,339
# ...                                     ...        ...      ...        ...
# 8630  2017/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)      1,285      -31        -31
# 8631  2018/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)      1,284      -93        -93
# 8632  2019/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)      1,211     -123       -123
# 8633  2020/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)      1,107       -7         -7
# 8634  2021/12\n\t\t\t\t\t\t\t\t\t\n(IFRS연결)        760       11         11
#
# ...

# %%
df_financial_statements = df_financial_statements.drop('Unnamed: 0', axis = 1)

# %%
df_financial_statements
# Out:
#             매출액     영업이익 영업이익(발표기준) 세전계속사업이익    당기순이익 당기순이익(지배) 당기순이익(비지배)  \
# 0     2,395,754  536,450    536,450  561,960  421,867   413,446      8,422
# 1     2,437,714  588,867    588,867  611,600  443,449   438,909      4,540
# 2     2,304,009  277,685    277,685  304,322  217,389   215,051      2,338
# 3     2,368,070  359,939    359,939  363,451  264,078   260,908      3,170
# 4     2,796,048  516,339    516,339  533,518  399,074   392,438      6,637
# ...         ...      ...        ...      ...      ...       ...        ...
# 8630      1,285      -31        -31        7        3         4         -1
# 8631      1,284      -93        -93     -187     -193      -188         -5
# 8632      1,211     -123       -123     -420     -370      -352        -18
# 8633      1,107       -7         -7      -52      -45       -40         -5
# 8634        760       11         11        0       10        11         -1
#
# ...

# %%
df_financial_statements.columns
# Out:
# Index(['매출액', '영업이익', '영업이익(발표기준)', '세전계속사업이익', '당기순이익', '당기순이익(지배)',
#        '당기순이익(비지배)', '자산총계', '부채총계', '자본총계', '자본총계(지배)', '자본총계(비지배)', '자본금',
#        '영업활동현금흐름', '투자활동현금흐름', '재무활동현금흐름', 'CAPEX', 'FCF', '이자발생부채', '영업이익률',
#        '순이익률', 'ROE(%)', 'ROA(%)', '부채비율', '자본유보율', 'EPS(원)', 'PER(배)',
#        'BPS(원)', 'PBR(배)', '현금DPS(원)', '현금배당수익률', '현금배당성향(%)', '발행주식수(보통주)',
#        'name', 'code', 'year'],
#       dtype='object')

# %%
df_financial_statements['CAPEX']
# Out:
# 0       427,922
# 1       295,564
# 2       253,678
# 3       375,920
# 4       471,221
#          ...
# 8630         57
# 8631         20
# 8632        183
# 8633          8
# 8634          2
# Name: CAPEX, Length: 8635, dtype: object
